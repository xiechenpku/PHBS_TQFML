# %% [markdown]
# # Data Information:
#
# ## Input variables:
#
#
# ## Output variable (desired target):

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# Import libraries and data, select a small sample set for trainning

# %%
from sklearn import datasets
import numpy as np
import pandas as pd
import copy
import matplotlib.pyplot as plt

lol_origin = pd.read_csv('./leagueoflegends/leagueoflegends.csv')
lol = lol_origin.copy()
lol.tail()
# Out:
#        bu  Year  Season    Type blueTeamTag  bResult  rResult redTeamTag  \
# 7615  TCL  2018  Spring  Season          YC        0        1        SUP
# 7616  TCL  2018  Spring  Season         GAL        0        1         DP
# 7617  OPL  2018  Spring  Season         SIN        0        1         DW
# 7618  OPL  2018  Spring  Season         LGC        1        0        TTC
# 7619  OPL  2018  Spring  Season         TTC        0        1        LGC
#
#       gamelength                                           golddiff  \
# 7615          34  [0, 0, -18, -95, 45, -87, -117, 199, 126, 92, ...
# 7616          39  [0, 0, -86, -39, -207, -349, -60, -140, 187, -...
# 7617          24  [0, -8, -6, 116, 103, -92, -470, -958, -1998, ...
# 7618          35  [0, 0, -97, 33, 351, 284, 299, 263, 403, 623, ...
# 7619          42  [0, 0, -8, -225, -36, 73, 464, 184, 1171, 1409...
#
#                             ...                         redMiddleChamp  \
# 7615                        ...                                 Veigar
# 7616                        ...                                   Ryze
# 7617                        ...                               Malzahar
# 7618                        ...                                 Veigar
# 7619                        ...                               Malzahar
#
#                                           goldredMiddle    redADC redADCChamp  \
# 7615  [500, 500, 632, 982, 1258, 1667, 2060, 2390, 2...   Zeitnot       Xayah
# 7616  [500, 500, 612, 1000, 1193, 1626, 1979, 2318, ...  Ruvelius     Caitlyn
# 7617  [500, 500, 615, 903, 1225, 1617, 1976, 2304, 2...      k1ng      Ezreal
# 7618  [500, 500, 561, 931, 1223, 1631, 1987, 2315, 2...       Low       Sivir
# 7619  [500, 500, 598, 968, 1165, 1477, 1801, 2016, 2...      Raid       Vayne
#
#                                              goldredADC  redSupport  \
# 7615  [500, 500, 564, 1027, 1320, 1727, 1963, 2276, ...  SnowFlower
# 7616  [500, 500, 621, 977, 1420, 1809, 2047, 2413, 2...      Japone
# 7617  [500, 508, 592, 986, 1400, 1753, 2196, 2538, 3...     Cupcake
# 7618  [500, 500, 634, 930, 1304, 1691, 2042, 2384, 2...     Tilting
# 7619  [500, 500, 587, 954, 1327, 1749, 2007, 2471, 2...       Decoy
#
#      redSupportChamp                                     goldredSupport  \
# 7615           Rakan  [500, 500, 566, 801, 1004, 1234, 1463, 1674, 1...
# 7616           Braum  [500, 500, 587, 790, 1107, 1335, 1472, 1616, 1...
# 7617           Taric  [500, 500, 585, 770, 976, 1222, 1446, 1627, 19...
# 7618           Janna  [500, 500, 592, 788, 1006, 1251, 1490, 1704, 1...
# 7619           Braum  [500, 500, 585, 793, 998, 1201, 1373, 1619, 18...
#
#                                                 redBans  \
# 7615     ['Ornn', 'Kalista', 'Ryze', 'Alistar', 'Shen']
# 7616    ['Zoe', 'KogMaw', 'JarvanIV', 'Ornn', 'Rengar']
# 7617  ['Azir', 'Kalista', 'Braum', 'Maokai', 'Alistar']
# 7618   ['Kalista', 'Galio', 'Gnar', 'Jayce', 'Sejuani']
# 7619   ['KogMaw', 'Illaoi', 'Azir', 'Karma', 'Sejuani']
#
#                                                 Address
# 7615  https://matchhistory.euw.leagueoflegends.com/e...
# 7616  https://matchhistory.euw.leagueoflegends.com/e...
# 7617  https://matchhistory.na.leagueoflegends.com/en...
# 7618  https://matchhistory.na.leagueoflegends.com/en...
# 7619  https://matchhistory.na.leagueoflegends.com/en...
#
# [5 rows x 57 columns]

# %%
#lol = lol_origin.drop(['goldblue','goldred','Address','bBarons','rBarons','redBans','blueBans',],1) 
#this is the way we treat 'player' as nominal variables

lol = lol_origin.drop(['goldblue','goldred','Address','bBarons','rBarons','redBans','blueBans','blueTop','blueMiddle','blueJungle','blueADC','blueSupport',
          'redTop','redMiddle','redJungle','redADC','redSupport'],1) 
# this is the way we treat 'player' as ordinal variables, therefore, we set them as dummies later

for x in ['golddiff','goldblueTop','goldblueJungle','goldblueMiddle','goldblueADC','goldblueSupport',
          'goldredTop','goldredJungle','goldredMiddle','goldredADC','goldredSupport']:
    lol[x] = [int(y.split(',')[14]) for y in lol_origin[x]]

for x in ['Top','Jungle','Middle','ADC','Support']:
    lol['golddiff' + x ] = lol['goldblue' + x ] - lol['goldred' + x ]
    del lol['goldblue' + x ]
    del lol['goldred' + x ]

# %%
def get_data15(feature):
    info = [x[2:-2] for x in feature]
    data15 = []
    for y in info:
        y = y.split('], [')
        j = 0
        for z in y:
            if z.strip() =='':
                break
            else:
                z=z.split(',')
                n =float(z[0])
                if n < 15.0 :
                    j = j + 1
        data15.append(j)
    return data15

# %%
for x in ['bKills','bTowers','bInhibs','bDragons','bHeralds',
          'rKills','rTowers','rInhibs','rDragons','rHeralds']:
    del lol[x]
    lol[x] = get_data15(lol_origin[x])

# %%
champ_names = lol_origin['blueTopChamp']
player_names = lol_origin['blueTop']
team_names = lol_origin['blueTeamTag']
for x in ['blueMiddleChamp','blueJungleChamp','blueADCChamp','blueSupportChamp',
          'redTopChamp','redMiddleChamp','redJungleChamp','redADCChamp','redSupportChamp']:
    champ_names = champ_names.append(lol_origin[x])
for x in ['blueMiddle','blueJungle','blueADC','blueSupport',
          'redTop','redMiddle','redJungle','redADC','redSupport']:
    player_names = player_names.append(lol_origin[x])
team_names = team_names.append(lol_origin['redTeamTag'])

# %% [markdown]
# ### Processing the ordinal and nominal data,seperately

# %%
from sklearn.preprocessing import LabelEncoder

def nominal_transform(names,sets):
    le = LabelEncoder()
    le.fit_transform(names.astype(str))
    for x in sets:
        lol[x] = le.transform(lol_origin[x].astype(str))

# %%
Position = ['blueTop','blueMiddle','blueJungle','blueADC','blueSupport',
          'redTop','redMiddle','redJungle','redADC','redSupport']
Champ = [x+'Champ' for x in Position]
Team = ['blueTeamTag','redTeamTag']
Other = ['bu','Season','Type']

nominal_transform(champ_names,Champ)
#nominal_transform(player_names,Position)   #this is the way we treat 'player' as nominal variables
nominal_transform(team_names,Team)

for x in Other:
    le = LabelEncoder()
    lol[x] = le.fit_transform(lol_origin[x].astype(str))

# %%
dummies_Player = pd.get_dummies(lol_origin[['blueTop','blueMiddle','blueJungle','blueADC','blueSupport',
          'redTop','redMiddle','redJungle','redADC','redSupport']])
# transform players' names into dummies

# %%
Champ_list = sorted(champ_names.unique())
lol_origin.redBans = lol_origin.redBans.str.strip('[]').str.replace("'",'')
lol_origin.blueBans = lol_origin.blueBans.str.strip('[]').str.replace("'",'')
dummies_Champ_Bans = pd.DataFrame(np.zeros((len(lol_origin),len(Champ_list))),columns=Champ_list)
for i, Champ in enumerate(lol_origin.redBans):
    Champ = str(Champ)
    for ban in Champ.split(', '):
        dummies_Champ_Bans.ix[i, ban] = 1
for i, Champ in enumerate(lol_origin.blueBans):
    Champ = str(Champ)
    for ban in Champ.split(', '):
        dummies_Champ_Bans.ix[i, ban] = 1
del dummies_Champ_Bans['']
lol = lol.join(dummies_Champ_Bans)
lol = lol.join(dummies_Player) # treat players as ordinal variables
#lol.to_excel('lol_players_nominal.xlsx')   # export nominal_player data into excel, ordinal data is too big to export.
# Out:
# D:\python3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix

# %%
y = lol['bResult']
X = lol.drop(['bResult','rResult'],1)

# %%
labels = 'BlueWin', 'RedWin'
sizes = [y.value_counts()[1],y.value_counts()[0]]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ### Splitting data into 70% training and 30% test data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y)

# %% [markdown]
# ### Bringing features onto the same scale(Standardization)

# %%
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
X_train = stdsc.fit_transform(X_train)
X_test = stdsc.transform(X_test)

# %% [markdown]
# # Feature Selection
#
# ## Sequential Backward Selection
#
# Here we want to use SBS method to select meaningful features

# %%
from sklearn.base import clone
from itertools import combinations
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


class SBS():
    def __init__(self, estimator, k_features, scoring=accuracy_score,
                 test_size=0.25, random_state=1):
        self.scoring = scoring
        self.estimator = clone(estimator)
        self.k_features = k_features
        self.test_size = test_size
        self.random_state = random_state

    def fit(self, X, y):
        
        X_train, X_test, y_train, y_test = \
            train_test_split(X, y, test_size=self.test_size,
                             random_state=self.random_state)

        dim = X_train.shape[1]
        self.indices_ = tuple(range(dim))
        self.subsets_ = [self.indices_]
        score = self._calc_score(X_train, y_train, 
                                 X_test, y_test, self.indices_)
        self.scores_ = [score]

        while dim > self.k_features:
            scores = []
            subsets = []

            for p in combinations(self.indices_, r=dim - 1):
                score = self._calc_score(X_train, y_train, 
                                         X_test, y_test, p)
                scores.append(score)
                subsets.append(p)

            best = np.argmax(scores)
            self.indices_ = subsets[best]
            self.subsets_.append(self.indices_)
            dim -= 1

            self.scores_.append(scores[best])
        self.k_score_ = self.scores_[-1]

        return self

    def transform(self, X):
        return X[:, self.indices_]

    def _calc_score(self, X_train, y_train, X_test, y_test, indices):
        self.estimator.fit(X_train[:, indices], y_train)
        y_pred = self.estimator.predict(X_test[:, indices])
        score = self.scoring(y_test, y_pred)
        return score

# %% [markdown]
# ### SBS  function

# %%
from sklearn.svm import SVC

def sbs_selection(model,X_train,y_train):
    # selecting features
    sbs = SBS(model, k_features=1)
    sbs.fit(X_train, y_train)

    # plotting performance of feature subsets
    k_feat = [len(k) for k in sbs.subsets_]
    plt.plot(k_feat, sbs.scores_, marker='o')
    plt.ylim([0.5, 1.02])
    plt.ylabel('Accuracy')
    plt.xlabel('Number of features')
    plt.grid()
    plt.tight_layout()
    plt.show()
    
    model.fit(X_train, y_train)
    print('accuracy of trainning = ' ,model.score(X_train,y_train))
    print('accuracy of testing = ' ,model.score(X_test,y_test))

# %%
#lr = LogisticRegression(penalty='l1',C=1,random_state=1)
#sbs_selection(lr,X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-9cc21b4b4e78> in <module>()
#       1 lr = LogisticRegression(penalty='l1',C=1,random_state=1)
# ----> 2 sbs_selection(lr,X_train,y_train)
#
# <ipython-input-35-926f262418cc> in sbs_selection(model, X_train, y_train)
#       5     # selecting features
#       6     sbs = SBS(model, k_features=1)
# ----> 7     sbs.fit(X_train, y_train)
#       8
#       9     # plotting performance of feature subsets
#
# <ipython-input-34-bf413ececa9b> in fit(self, X, y)
#      33             for p in combinations(self.indices_, r=dim - 1):
#      34                 score = self._calc_score(X_train, y_train,
# ---> 35                                          X_test, y_test, p)
#      36                 scores.append(score)
#      37                 subsets.append(p)
#
# <ipython-input-34-bf413ececa9b> in _calc_score(self, X_train, y_train, X_test, y_test, indices)
#      51
#      52     def _calc_score(self, X_train, y_train, X_test, y_test, indices):
# ---> 53         self.estimator.fit(X_train[:, indices], y_train)
#      54         y_pred = self.estimator.predict(X_test[:, indices])
#      55         score = self.scoring(y_test, y_pred)
#
# D:\python3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1184                 self.class_weight, self.penalty, self.dual, self.verbose,
#    1185                 self.max_iter, self.tol, self.random_state,
# -> 1186                 sample_weight=sample_weight)
#    1187             self.n_iter_ = np.array([n_iter_])
#    1188             return self
#
# D:\python3\lib\site-packages\sklearn\svm\base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     910         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     911         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 912         epsilon, sample_weight)
#     913     # Regarding rnd.randint(..) in the above signature:
#     914     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %% [markdown]
# ## PCA Selection

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.decomposition import PCA
pca = PCA(n_components=None)
X_train_pca = pca.fit_transform(X_train)
pca.explained_variance_ratio_
# Out:
# array([  3.39764233e-03,   3.10170477e-03,   2.98932263e-03, ...,
#          7.75947925e-40,   6.45099258e-40,   5.05465661e-40])

# %%
plt.bar(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_, alpha=0.5, align='center')
plt.step(range(1, len(pca.explained_variance_ratio_)+1), np.cumsum(pca.explained_variance_ratio_), where='mid')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')

plt.show()

# %%
pca = PCA(n_components=2000)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
lr = LogisticRegression(penalty='l1',C=0.01,random_state=1)
lr = lr.fit(X_train_pca, y_train)
print('accuracy of trainning = ' ,lr.score(X_train_pca,y_train))
print('accuracy of testing = ' ,lr.score(X_test_pca,y_test))
# Out:
# accuracy of trainning =  0.749156355456
# accuracy of testing =  0.727034120735

# %% [markdown]
# ## Random Forest Selection

# %%
from sklearn.ensemble import RandomForestClassifier

feat_labels = lol.columns[1:]

forest = RandomForestClassifier(n_estimators=500,
                                random_state=1)

forest.fit(X_train, y_train)
importances = forest.feature_importances_

indices = np.argsort(importances)[::-1]


for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, 
                            feat_labels[indices[f]], 
                            importances[indices[f]]))

plt.title('Feature Importance')
plt.bar(range(X_train.shape[1]), 
        importances[indices],
        align='center')

plt.xticks(range(X_train.shape[1]), 
           feat_labels[indices], rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.tight_layout()
plt.show()
# Out:
#  1) gamelength                     0.052706
#  2) golddiffMiddle                 0.033660
#  3) golddiffJungle                 0.033570
#  4) golddiffTop                    0.030872
#  5) golddiffADC                    0.029763
#  6) redSupportChamp                0.029540
#  7) redTeamTag                     0.019497
#  8) golddiffSupport                0.019181
#  9) bHeralds                       0.017946
# 10) rInhibs                        0.017098
# 11) bInhibs                        0.012347
# 12) rKills                         0.011941
# 13) golddiff                       0.011106
# 14) rResult                        0.011008
# 15) bResult                        0.010705
# 16) redJungleChamp                 0.010660
# 17) blueSupportChamp               0.010587
# 18) blueJungleChamp                0.010328
# 19) bKills                         0.010120
# 20) blueTopChamp                   0.009607
# 21) blueADCChamp                   0.009524
# 22) redTopChamp                    0.009282
# 23) blueMiddleChamp                0.009101
# 24) redMiddleChamp                 0.009037
# 25) redADCChamp                    0.008688
# 26) Year                           0.006707
# 27) Season                         0.003981
# 28) blueTeamTag                    0.003766
# 29) bDragons                       0.002519
# 30) Type                           0.002508
# 31) rDragons                       0.002508
# 32) KogMaw                         0.002474
# 33) Rumble                         0.002445
# 34) Ekko                           0.002338
# 35) Jinx                           0.002316
# 36) Swain                          0.002277
# 37) Shaco                          0.002200
# 38) Nautilus                       0.002185
# 39) Lucian                         0.002136
# 40) Camille                        0.001996
# 41) Braum                          0.001970
# 42) Riven                          0.001962
# 43) Rammus                         0.001904
# 44) Gnar                           0.001904
# 45) Teemo                          0.001830
# 46) Caitlyn                        0.001828
# 47) Jax                            0.001804
# 48) Viktor                         0.001803
# 49) AurelionSol                    0.001798
# 50) Syndra                         0.001797
# 51) Urgot                          0.001761
# 52) Fiddlesticks                   0.001717
# 53) Malphite                       0.001704
# 54) Malzahar                       0.001697
# 55) Akali                          0.001681
# 56) Yorick                         0.001678
# 57) Kalista                        0.001668
# 58) Galio                          0.001659
# 59) Olaf                           0.001657
# 60) TahmKench                      0.001650
# 61) Leblanc                        0.001598
# 62) Renekton                       0.001583
# 63) Gragas                         0.001560
# 64) Kayn                           0.001535
# 65) Garen                          0.001534
# 66) Sion                           0.001529
# 67) Zoe                            0.001498
# 68) Fizz                           0.001498
# 69) Chogath                        0.001482
# 70) Brand                          0.001481
# 71) Zac                            0.001475
# 72) Karthus                        0.001473
# 73) Tristana                       0.001438
# 74) redSupport_Wildpanda           0.001435
# 75) Annie                          0.001379
# 76) Lissandra                      0.001283
# 77) redADC_BULBAZABP               0.001280
# 78) Pantheon                       0.001250
# 79) redMiddle_Exosen               0.001244
# 80) Janna                          0.001236
# 81) Khazix                         0.001235
# 82) Ryze                           0.001226
# 83) Leona                          0.001222
# 84) Fiora                          0.001216
# 85) Kled                           0.001209
# 86) Kennen                         0.001201
# 87) Azir                           0.001183
# 88) Draven                         0.001174
# 89) RekSai                         0.001171
# 90) Vi                             0.001119
# 91) Evelynn                        0.001108
# 92) blueSupport_Wildpanda          0.001083
# 93) Jayce                          0.001075
# 94) blueADC_BULBAZABP              0.001064
# 95) Tryndamere                     0.001059
# 96) redMiddle_Innox                0.001045
# 97) redTop_Hipo                    0.001030
# 98) Cassiopeia                     0.001024
# 99) Graves                         0.001010
# 100) Aatrox                         0.001009
# 101) Mordekaiser                    0.001008
# 102) redTop_SkyBart                 0.000998
# 103) Quinn                          0.000995
# 104) Warwick                        0.000982
# 105) redTop_Huni                    0.000953
# 106) Irelia                         0.000941
# 107) Nasus                          0.000939
# 108) Ziggs                          0.000933
# 109) redMiddle_Bischu               0.000892
# 110) redMiddle_Magico               0.000886
# 111) redJungle_Kanani               0.000886
# 112) Nunu                           0.000876
# 113) blueMiddle_Exosen              0.000869
# 114) blueTop_Nexus                  0.000865
# 115) Bard                           0.000863
# 116) JarvanIV                       0.000860
# 117) redADC_Smlz                    0.000853
# 118) redTop_HanShao                 0.000838
# 119) Ashe                           0.000833
# 120) redJungle_Amazingx             0.000823
# 121) blueTop_MMD                    0.000795
# 122) redSupport_GoSu Pepper         0.000789
# 123) redMiddle_Crow                 0.000778
# 124) redADC_Police                  0.000774
# 125) blueMiddle_Bischu              0.000774
# 126) blueSupport_GoSu Pepper        0.000768
# 127) Ivern                          0.000767
# 128) Illaoi                         0.000760
# 129) blueTop_SkyBart                0.000754
# 130) redTop_ZionSpartan             0.000754
# 131) redADC_2020                    0.000748
# 132) blueMiddle_KuKu                0.000748
# 133) redJungle_Stomaged             0.000747
# 134) redADC_xpng                    0.000744
# 135) Thresh                         0.000734
# 136) Soraka                         0.000729
# 137) Amumu                          0.000728
# 138) redADC_Whitelotus              0.000719
# 139) blueMiddle_Pobelter            0.000719
# 140) redSupport_Air                 0.000717
# 141) blueADC_Police                 0.000713
# 142) redJungle_Trashy               0.000711
# 143) redJungle_Steal                0.000708
# 144) blueJungle_Cboi                0.000702
# 145) redJungle_Savage               0.000701
# 146) TwistedFate                    0.000695
# 147) redTop_Moracras                0.000691
# 148) blueADC_DoubleRed              0.000691
# 149) redTop_MANTARRAYA              0.000691
# 150) redSupport_masterwork          0.000689
# 151) redTop_Send0o                  0.000686
# 152) blueJungle_Savage              0.000686
# 153) redMiddle_PerkZ                0.000681
# 154) redJungle_Morning              0.000680
# 155) blueJungle_Reach               0.000679
# 156) redTop_Soul                    0.000674
# 157) redTop_Verto                   0.000674
# 158) redSupport_Hybrid              0.000669
# 159) redTop_Crisange                0.000669
# 160) blueADC_Zeicro                 0.000668
# 161) redSupport_Slow                0.000662
# 162) redADC_An                      0.000660
# 163) redADC_Znsho                   0.000660
# 164) redSupport_Japone              0.000655
# 165) redTop_Lord ZaK                0.000654
# 166) blueADC_Samux                  0.000651
# 167) redMiddle_KuKu                 0.000649
# 168) blueADC_Smlz                   0.000646
# 169) blueMiddle_Mega                0.000643
# 170) blueTop_Hanabi                 0.000640
# 171) redMiddle_Kawai                0.000637
# 172) blueTop_Hipo                   0.000637
# 173) blueJungle_Xerxe               0.000634
# 174) blueJungle_Stomaged            0.000634
# 175) Taliyah                        0.000630
# 176) blueTop_NoNholy                0.000628
# 177) blueADC_Reje                   0.000627
# 178) redJungle_Condi                0.000627
# 179) redMiddle_Fly                  0.000626
# 180) Kindred                        0.000623
# 181) blueSupport_Smoothie           0.000620
# 182) redADC_Zeicro                  0.000620
# 183) blueADC_Apollo                 0.000619
# 184) redSupport_Sweetr              0.000617
# 185) redSupport_Hai                 0.000614
# 186) blueMiddle_Ryavka              0.000613
# 187) blueMiddle_Fate                0.000612
# 188) blueTop_Crisange               0.000610
# 189) redTop_Evi                     0.000606
# 190) blueMiddle_Magebane            0.000606
# 191) redJungle_Paz                  0.000605
# 192) redADC_Apollo                  0.000604
# 193) blueMiddle_Plugo               0.000601
# 194) redTop_NoNholy                 0.000598
# 195) redMiddle_Ryavka               0.000596
# 196) redSupport_Dreams              0.000596
# 197) Poppy                          0.000594
# 198) blueTop_Soul                   0.000593
# 199) blueSupport_Zzus               0.000593
# 200) redJungle_LiquidDiego          0.000584
# 201) blueMiddle_Crossman            0.000568
# 202) redSupport_Coool               0.000566
# 203) redSupport_Ceos                0.000563
# 204) blueJungle_Amazingx            0.000563
# 205) redADC_Rokenia                 0.000562
# 206) blueTop_Babunia                0.000561
# 207) blueJungle_Paz                 0.000559
# 208) redJungle_Cboi                 0.000556
# 209) blueADC_Stitch                 0.000556
# 210) redMiddle_Nagne                0.000555
# 211) blueSupport_Big                0.000554
# 212) blueSupport_Lelouch            0.000554
# 213) redJungle_Xerxe                0.000553
# 214) blueJungle_SpeaR               0.000553
# 215) blueJungle_LiquidDiego         0.000551
# 216) blueTop_Thal                   0.000551
# 217) Morgana                        0.000550
# 218) blueTop_Darlik                 0.000548
# 219) Anivia                         0.000548
# 220) blueTop_ZionSpartan            0.000545
# 221) redADC_DoubleRed               0.000544
# 222) blueSupport_Air                0.000544
# 223) redSupport_Mata                0.000542
# 224) blueSupport_Hybrid             0.000542
# 225) redADC_Stealthix               0.000541
# 226) blueTop_Verto                  0.000534
# 227) redJungle_Xayoo                0.000534
# 228) blueJungle_Inu                 0.000534
# 229) redMiddle_Evrot                0.000534
# 230) redMiddle_Fate                 0.000532
# 231) redMiddle_G4                   0.000532
# 232) blueSupport_Xavieles           0.000530
# 233) redSupport_Dodo8               0.000528
# 234) blueSupport_Ceos               0.000525
# 235) blueSupport_Hylissang          0.000520
# 236) blueADC_Frost                  0.000519
# 237) blueMiddle_Frae                0.000518
# 238) blueTop_Lord ZaK               0.000518
# 239) redADC_N1njA                   0.000517
# 240) redTop_Tornell                 0.000516
# 241) blueADC_Whitelotus             0.000515
# 242) redJungle_RD                   0.000515
# 243) redTop_iScarface               0.000515
# 244) redSupport_Big                 0.000514
# 245) MasterYi                       0.000511
# 246) redTop_Doxy                    0.000511
# 247) redTop_Bwipo                   0.000510
# 248) redMiddle_Plugo                0.000510
# 249) blueMiddle_HuHi                0.000510
# 250) Varus                          0.000507
# 251) blueJungle_Adaniel             0.000506
# 252) redSupport_Xavieles            0.000504
# 253) blueMiddle_Kawai               0.000500
# 254) blueSupport_Skash              0.000500
# 255) blueSupport_Slow               0.000499
# 256) blueMiddle_Flezeth             0.000499
# 257) redADC_Safir                   0.000498
# 258) blueMiddle_Lvsyan              0.000496
# 259) blueTop_raizin                 0.000496
# 260) redADC_Frost                   0.000495
# 261) blueTop_xSWRD                  0.000495
# 262) blueJungle_Kanani              0.000494
# 263) blueMiddle_Bdoink              0.000493
# 264) blueMiddle_Froggen             0.000493
# 265) blueSupport_Mata               0.000492
# 266) blueMiddle_Innox               0.000489
# 267) blueJungle_Morning             0.000487
# 268) redJungle_Beyond               0.000487
# 269) blueSupport_Dodo8              0.000486
# 270) blueADC_Noway                  0.000485
# 271) blueSupport_G0DFRED            0.000483
# 272) redADC_Kobbe                   0.000483
# 273) redSupport_Smoothie            0.000482
# 274) Sona                           0.000481
# 275) redADC_Phantiks                0.000481
# 276) blueJungle_Baybay              0.000480
# 277) Udyr                           0.000479
# 278) blueMiddle_G4                  0.000479
# 279) blueSupport_Nyph               0.000478
# 280) redADC_Noway                   0.000478
# 281) redMiddle_Mega                 0.000478
# 282) blueJungle_Steal               0.000478
# 283) blueTop_Send0o                 0.000474
# 284) redADC_Reje                    0.000471
# 285) redSupport_Lelouch             0.000470
# 286) redADC_Piglet                  0.000470
# 287) redTop_Babunia                 0.000465
# 288) blueTop_iScarface              0.000464
# 289) blueADC_Aladoric               0.000464
# 290) redJungle_Reach                0.000461
# 291) redADC_LBB                     0.000460
# 292) blueADC_Stealthix              0.000460
# 293) Talon                          0.000460
# 294) blueSupport_Grisen             0.000458
# 295) redJungle_Saintvicious         0.000458
# 296) redADC_Samux                   0.000455
# 297) redSupport_Lustboy             0.000455
# 298) blueADC_SONSTAR                0.000455
# 299) blueADC_Day1                   0.000453
# 300) redMiddle_Kuro                 0.000453
# 301) blueMiddle_HW4NG               0.000451
# 302) redJungle_Inu                  0.000450
# 303) blueSupport_Dreams             0.000449
# 304) redSupport_Mallek              0.000447
# 305) redADC_Day1                    0.000447
# 306) blueADC_Kobbe                  0.000447
# 307) blueSupport_Zeyzal             0.000446
# 308) blueSupport_Keoo               0.000445
# 309) redJungle_Mess                 0.000445
# 310) blueADC_An                     0.000445
# 311) redADC_Breaker                 0.000444
# 312) blueADC_Kedu                   0.000443
# 313) blueADC_Rokenia                0.000441
# 314) blueMiddle_Easyhoon            0.000440
# 315) Heimerdinger                   0.000438
# 316) blueTop_Expect                 0.000437
# 317) blueJungle_Malrang             0.000436
# 318) blueADC_Phantiks               0.000435
# 319) blueADC_Znsho                  0.000434
# 320) redMiddle_Easyhoon             0.000433
# 321) redSupport_Zzus                0.000432
# 322) blueJungle_Trashy              0.000431
# 323) redMiddle_Pobelter             0.000430
# 324) blueSupport_sonyky             0.000429
# 325) blueJungle_Saintvicious        0.000428
# 326) blueSupport_Woswos             0.000428
# 327) blueJungle_Blank               0.000426
# 328) redADC_Dee                     0.000426
# 329) redADC_MabreyBABY              0.000425
# 330) redJungle_Baybay               0.000425
# 331) blueJungle_Shini               0.000421
# 332) blueSupport_Coool              0.000421
# 333) blueMiddle_slooshi8            0.000420
# 334) blueTop_Akunma                 0.000420
# 335) blueMiddle_Fly                 0.000419
# 336) blueADC_Straawbella            0.000419
# 337) redJungle_Taikki               0.000418
# 338) redMiddle_Icytower             0.000417
# 339) blueJungle_Wolf                0.000417
# 340) blueTop_Bwipo                  0.000417
# 341) redADC_Aladoric                0.000417
# 342) redSupport_Unlimited           0.000416
# 343) redSupport_SwordArT            0.000416
# 344) redTop_Survivalone             0.000416
# 345) blueMiddle_Candy               0.000416
# 346) blueTop_Tornell                0.000415
# 347) redMiddle_Night                0.000414
# 348) redTop_xSWRD                   0.000414
# 349) blueTop_Kiin                   0.000412
# 350) blueJungle_Taikki              0.000411
# 351) XinZhao                        0.000411
# 352) redMiddle_HW4NG                0.000411
# 353) redMiddle_Huhi                 0.000406
# 354) redJungle_Crush                0.000405
# 355) redSupport_Matt                0.000404
# 356) redTop_957                     0.000404
# 357) redTop_Eledion                 0.000404
# 358) redMiddle_Kerp                 0.000403
# 359) redADC_Bat                     0.000403
# 360) redTop_Sharp                   0.000402
# 361) redMiddle_Froggen              0.000396
# 362) blueADC_2020                   0.000396
# 363) redSupport_Nyph                0.000395
# 364) blueSupport_SwordArT           0.000395
# 365) blueMiddle_Takefuned           0.000394
# 366) blueSupport_masterwork         0.000394
# 367) blueJungle_Juliostito          0.000393
# 368) blueSupport_Unlimited          0.000393
# 369) Zilean                         0.000393
# 370) redMiddle_Frae                 0.000393
# 371) blueMiddle_Night               0.000392
# 372) redJungle_SpeaR                0.000392
# 373) redMiddle_Ceros                0.000392
# 374) blueMiddle_S Ysera             0.000389
# 375) redADC_SONSTAR                 0.000388
# 376) blueTop_Idyiom                 0.000387
# 377) redJungle_Mountain             0.000387
# 378) Zed                            0.000386
# 379) blueJungle_Mountain            0.000384
# 380) blueSupport_Stuntopolis        0.000383
# 381) redSupport_PromisQ             0.000382
# 382) blueADC_Piglet                 0.000381
# 383) redJungle_Dandy                0.000381
# 384) blueMiddle_Kuro                0.000378
# 385) redJungle_Caos                 0.000378
# 386) blueADC_HeaQ                   0.000378
# 387) blueADC_LBB                    0.000378
# 388) redTop_Unknown                 0.000377
# 389) blueJungle_Moojin              0.000376
# 390) Orianna                        0.000376
# 391) redTop_Jer0m                   0.000376
# 392) redMiddle_Fomko                0.000375
# 393) blueMiddle_Pekin Woof          0.000374
# 394) redADC_j1mmy                   0.000373
# 395) blueADC_Bat                    0.000373
# 396) blueADC_Moopz                  0.000372
# 397) redTop_Darlik                  0.000372
# 398) blueMiddle_Nagne               0.000371
# 399) blueSupport_Lustboy            0.000371
# 400) blueADC_Grisha                 0.000370
# 401) redSupport_Grisen              0.000369
# 402) redMiddle_CoCo                 0.000367
# 403) redJungle_BetongJocke          0.000367
# 404) redADC_HeaQ                    0.000366
# 405) redADC_Rabi2                   0.000366
# 406) blueSupport_Japone             0.000365
# 407) blueJungle_Mess                0.000365
# 408) redADC_Stitch                  0.000365
# 409) blueTop_Doxy                   0.000364
# 410) blueSupport_Masterwork         0.000363
# 411) redMiddle_Flezeth              0.000363
# 412) blueADC_y4                     0.000362
# 413) blueTop_BloodFenix             0.000360
# 414) blueTop_CoolG                  0.000360
# 415) blueADC_M17Dee                 0.000360
# 416) redMiddle_SuwaKo               0.000358
# 417) Kassadin                       0.000358
# 418) redJungle_Winds                0.000357
# 419) redMiddle_Bdoink               0.000357
# 420) blueMiddle_Fomko               0.000357
# 421) blueSupport_Kairos Plz         0.000356
# 422) blueSupport_Hai                0.000356
# 423) blueMiddle_Evrot               0.000353
# 424) redJungle_Hard                 0.000350
# 425) blueJungle_Dandy               0.000350
# 426) redMiddle_HuHi                 0.000349
# 427) redTop_Never                   0.000349
# 428) redSupport_Xpecial             0.000348
# 429) blueTop_Evi                    0.000348
# 430) blueSupport_Tolerant           0.000347
# 431) redMiddle_AlexIch              0.000347
# 432) blueMiddle_CoCo                0.000347
# 433) redTop_Charger                 0.000346
# 434) blueJungle_Crumbzz             0.000346
# 435) redJungle_Mei                  0.000346
# 436) redMiddle_Cepted               0.000345
# 437) blueADC_Breaker                0.000344
# 438) blueSupport_Rogu sama          0.000343
# 439) blueTop_Steak                  0.000341
# 440) redSupport_EDward              0.000341
# 441) redTop_MMD                     0.000341
# 442) redTop_Expect                  0.000341
# 443) blueADC_Tour                   0.000340
# 444) blueMiddle_GoldenGlue          0.000340
# 445) blueTop_Charger                0.000338
# 446) redSupport_Jay                 0.000337
# 447) blueTop_LongB                  0.000337
# 448) redJungle_Winged               0.000336
# 449) blueMiddle_Huhi                0.000336
# 450) redSupport_Woswos              0.000336
# 451) redSupport_Gemp                0.000335
# 452) redSupport_Hylissang           0.000335
# 453) redTop_Ever Crazy              0.000334
# 454) blueMiddle_Icytower            0.000334
# 455) redSupport_Guger               0.000334
# 456) redADC_Hologram                0.000334
# 457) blueJungle_Score               0.000333
# 458) Xayah                          0.000333
# 459) blueJungle_Totti               0.000333
# 460) redJungle_Totti                0.000332
# 461) blueSupport_Guger              0.000332
# 462) blueJungle_Euphony             0.000331
# 463) redSupport_Key                 0.000331
# 464) redTop_FivetoEight             0.000331
# 465) blueMiddle_Selfie              0.000330
# 466) blueSupport_Tuna               0.000330
# 467) redMiddle_Nomanz               0.000329
# 468) blueADC_Kinzu                  0.000328
# 469) MonkeyKing                     0.000328
# 470) blueTop_Malaz                  0.000327
# 471) blueTop_fabfabulous            0.000327
# 472) redJungle_Spooky               0.000326
# 473) redJungle_Obvious              0.000324
# 474) redSupport_sonyky              0.000324
# 475) redSupport_Yuzuki              0.000323
# 476) Elise                          0.000323
# 477) blueMiddle_Kerp                0.000323
# 478) blueJungle_Yampi               0.000322
# 479) redSupport_G0DFRED             0.000322
# 480) blueTop_Sharp                  0.000322
# 481) Corki                          0.000322
# 482) redTop_Wickd                   0.000322
# 483) blueSupport_Promisq            0.000321
# 484) blueSupport_Jelly              0.000321
# 485) redJungle_Moojin               0.000321
# 486) blueTop_Hioss                  0.000321
# 487) redTop_Nipphu                  0.000321
# 488) redMiddle_Febiven              0.000320
# 489) blueSupport_Melon              0.000319
# 490) blueMiddle_Naehyun             0.000318
# 491) blueTop_Unknown                0.000317
# 492) redMiddle_Toyz                 0.000317
# 493) redTop_Kiin                    0.000317
# 494) redSupport_k1                  0.000316
# 495) redMiddle_PawN                 0.000315
# 496) redJungle_Shini                0.000315
# 497) blueMiddle_AlexIch             0.000315
# 498) blueJungle_Razelock            0.000315
# 499) blueTop_Eledion                0.000314
# 500) redADC_M17Dee                  0.000314
# 501) redTop_Flaxxish                0.000314
# 502) blueSupport_Yuzuki             0.000314
# 503) blueADC_Frae                   0.000313
# 504) redMiddle_Doinb                0.000313
# 505) redMiddle_Selfie               0.000313
# 506) blueADC_Kz                     0.000313
# 507) blueADC_Deee                   0.000312
# 508) blueJungle_BetongJocke         0.000312
# 509) redTop_raizin                  0.000312
# 510) blueADC_Ciyansan               0.000310
# 511) redADC_Ciyansan                0.000310
# 512) blueADC_MarioMe                0.000310
# 513) redJungle_Zahe                 0.000309
# 514) blueTop_957                    0.000309
# 515) blueTop_Moonblackk             0.000308
# 516) blueJungle_Condi               0.000307
# 517) redMiddle_Candy                0.000306
# 518) redMiddle_Lvsyan               0.000306
# 519) blueADC_Haretti                0.000306
# 520) redMiddle_Baxauer              0.000305
# 521) blueMiddle_Baxauer             0.000305
# 522) blueTop_FivetoEight            0.000305
# 523) blueJungle_Seb                 0.000304
# 524) blueSupport_tei                0.000304
# 525) blueTop_Solo                   0.000303
# 526) blueJungle_Crush               0.000302
# 527) blueJungle_Broken Blade        0.000302
# 528) redJungle_Pridestalker         0.000302
# 529) blueSupport_Matt               0.000302
# 530) redTop_PvPStejos               0.000302
# 531) redADC_MarioMe                 0.000301
# 532) blueSupport_Lounet             0.000301
# 533) blueMiddle_Immortoru           0.000301
# 534) redADC_Ruve sama               0.000301
# 535) redJungle_Alex                 0.000301
# 536) blueADC_j1mmy                  0.000300
# 537) redMiddle_ChrisMisTrees        0.000300
# 538) blueMiddle_Perkz               0.000299
# 539) blueMiddle_PawN                0.000299
# 540) blueJungle_Reignover           0.000298
# 541) redADC_FORG1VEN                0.000298
# 542) blueTop_Wickd                  0.000298
# 543) blueJungle_Beyond              0.000297
# 544) redJungle_Swift                0.000295
# 545) redADC_Kedu                    0.000295
# 546) redADC_Bebe                    0.000295
# 547) redJungle_Rudy                 0.000293
# 548) blueSupport_DaDa777            0.000293
# 549) blueADC_Cop                    0.000293
# 550) blueSupport_Xpecial            0.000292
# 551) redSupport_Tuna                0.000292
# 552) blueSupport_HusTlin            0.000292
# 553) blueJungle_Alex                0.000292
# 554) blueTop_Lilac                  0.000292
# 555) blueJungle_Obvious             0.000292
# 556) Vayne                          0.000291
# 557) redMiddle_S Ysera              0.000291
# 558) redADC_Hans sama               0.000291
# 559) redTop_Taki                    0.000291
# 560) blueJungle_Corn                0.000291
# 561) redTop_Smoke                   0.000290
# 562) redMiddle_Naehyun              0.000290
# 563) redSupport_Jelly               0.000290
# 564) blueADC_GodJJ                  0.000289
# 565) blueTop_Mouse                  0.000288
# 566) redADC_Kkramer                 0.000287
# 567) redMiddle_Takefuned            0.000287
# 568) blueTop_MANTARRAYA             0.000286
# 569) blueADC_Uzi                    0.000286
# 570) redSupport_Libik               0.000286
# 571) blueADC_N1njA                  0.000284
# 572) blueTop_Smoke                  0.000284
# 573) redSupport_Melon               0.000284
# 574) redADC_Warangelus              0.000284
# 575) blueADC_Kid                    0.000283
# 576) blueJungle_Winged              0.000283
# 577) redTop_Steak                   0.000283
# 578) redMiddle_GoldenGlue           0.000283
# 579) redJungle_Gemini               0.000283
# 580) redTop_Malaz                   0.000282
# 581) redJungle_Juliostito           0.000282
# 582) redSupport_Keoo                0.000282
# 583) blueJungle_Zahe                0.000281
# 584) redTop_CoolG                   0.000281
# 585) blueTop_Porky                  0.000280
# 586) redTop_SmittyJ                 0.000279
# 587) redMiddle_xPePii               0.000279
# 588) redJungle_TusiN                0.000278
# 589) redADC_Moopz                   0.000277
# 590) blueTop_Ruin                   0.000277
# 591) blueADC_Mash                   0.000277
# 592) redADC_Haretti                 0.000277
# 593) redTop_LongB                   0.000277
# 594) blueADC_Zyzz                   0.000276
# 595) redTop_fabfabulous             0.000275
# 596) blueADC_Lloyd                  0.000275
# 597) redJungle_ILLusion             0.000275
# 598) redJungle_Chaser               0.000274
# 599) blueSupport_Gemp               0.000274
# 600) redSupport_Bubbadub            0.000273
# 601) redTop_Xiyang                  0.000272
# 602) redMiddle_tinowns              0.000272
# 603) redJungle_Blank                0.000271
# 604) blueTop_Jer0m                  0.000271
# 605) blueSupport_Beni               0.000271
# 606) blueSupport_Sweetr             0.000271
# 607) blueJungle_Spooky              0.000271
# 608) blueADC_Ruve sama              0.000270
# 609) blueJungle_Hard                0.000270
# 610) redMiddle_Kyle                 0.000270
# 611) blueTop_Atom                   0.000269
# 612) redTop_BloodFenix              0.000269
# 613) blueSupport_Libik              0.000269
# 614) redJungle_Diamond              0.000269
# 615) blueTop_Xyraz                  0.000269
# 616) blueADC_Bebe                   0.000268
# 617) redSupport_Ella                0.000268
# 618) redJungle_NAZ                  0.000268
# 619) blueADC_deft                   0.000267
# 620) redTop_Thal                    0.000266
# 621) DrMundo                        0.000266
# 622) blueJungle_Dinter              0.000265
# 623) blueTop_Rascal                 0.000265
# 624) redADC_Vincent                 0.000264
# 625) blueTop_Roach                  0.000264
# 626) blueADC_Achuu Cop              0.000263
# 627) redADC_pooh                    0.000263
# 628) redJungle_U Jun                0.000263
# 629) blueADC_pooh                   0.000263
# 630) blueJungle_Caos                0.000262
# 631) blueMiddle_PaSa                0.000262
# 632) blueSupport_Key                0.000262
# 633) redMiddle_Search               0.000261
# 634) blueMiddle_Nomanz              0.000261
# 635) blueADC_Vincent                0.000260
# 636) redSupport_HusTlin             0.000260
# 637) blueTop_PvPStejos              0.000260
# 638) blueJungle_Mightybear          0.000259
# 639) blueJungle_Wikko               0.000259
# 640) blueTop_Flaxxish               0.000259
# 641) redSupport_Scatz               0.000259
# 642) redSupport_Klaj                0.000259
# 643) redTop_Duke                    0.000259
# 644) blueADC_CoreJJ                 0.000258
# 645) Volibear                       0.000258
# 646) blueTop_Never                  0.000258
# 647) redADC_meanTnT                 0.000257
# 648) redJungle_Malrang              0.000257
# 649) blueJungle_Punisher            0.000257
# 650) redSupport_Rogu sama           0.000256
# 651) blueMiddle_umuut               0.000255
# 652) blueADC_Warangelus             0.000254
# 653) blueTop_AJun                   0.000254
# 654) blueJungle_GalB                0.000254
# 655) blueJungle_Airwaks             0.000254
# 656) redMiddle_Lucete               0.000253
# 657) blueSupport_Jay                0.000253
# 658) redSupport_Luna                0.000253
# 659) redJungle_Broken Blade         0.000253
# 660) redJungle_MikeYeung            0.000253
# 661) redSupport_Minkywhale          0.000252
# 662) redMiddle_wtcN                 0.000252
# 663) blueJungle_Swift               0.000252
# 664) redADC_NaeMisa                 0.000252
# 665) redJungle_Khynm                0.000251
# 666) blueADC_Tauren                 0.000251
# 667) Nocturne                       0.000251
# 668) redMiddle_uri                  0.000251
# 669) blueTop_Duke                   0.000250
# 670) blueSupport_Luna               0.000250
# 671) blueSupport_Scatz              0.000249
# 672) blueMiddle_BoBo                0.000249
# 673) redTop_ackerman                0.000249
# 674) blueJungle_Winds               0.000249
# 675) redMiddle_FeniX                0.000248
# 676) blueSupport_Codpiece           0.000248
# 677) blueTop_Nipphu                 0.000248
# 678) blueSupport_Hustlin            0.000247
# 679) blueADC_Elysion                0.000247
# 680) redADC_Germoo                  0.000246
# 681) redSupport_un1tback            0.000246
# 682) blueSupport_EDward             0.000245
# 683) redJungle_Lasagna              0.000244
# 684) redADC_padden                  0.000244
# 685) blueADC_Focho                  0.000244
# 686) redADC_Sou                     0.000243
# 687) blueTop_Survivalone            0.000242
# 688) redTop_Solo                    0.000242
# 689) redSupport_Cotton              0.000242
# 690) redMiddle_Mugoon               0.000242
# 691) redADC_LeX                     0.000241
# 692) redMiddle_Eli                  0.000241
# 693) redSupport_DaDa777             0.000241
# 694) blueSupport_xPeke              0.000241
# 695) blueTop_Xiyang                 0.000240
# 696) blueMiddle_Ceros               0.000240
# 697) redSupport_Kairos Plz          0.000239
# 698) blueADC_NikSar                 0.000239
# 699) redSupport_Beni                0.000239
# 700) blueTop_ZvenE                  0.000238
# 701) redJungle_MiMo                 0.000238
# 702) blueADC_Germoo                 0.000237
# 703) redTop_Nexus                   0.000237
# 704) redADC_Betty                   0.000236
# 705) redJungle_Score                0.000236
# 706) Velkoz                         0.000235
# 707) redJungle_Mightybear           0.000235
# 708) redSupport_Wolf                0.000235
# 709) blueMiddle_tinowns             0.000234
# 710) redADC_Tauren                  0.000233
# 711) redJungle_Razelock             0.000233
# 712) redSupport_Dumbledoge          0.000233
# 713) redMiddle_umuut                0.000233
# 714) redTop_exciting                0.000232
# 715) blueJungle_Mei                 0.000232
# 716) redJungle_lira                 0.000232
# 717) blueJungle_RD                  0.000232
# 718) blueJungle_Trick               0.000232
# 719) blueMiddle_K                   0.000231
# 720) blueADC_Vasilii                0.000231
# 721) redMiddle_Wzrd                 0.000230
# 722) blueSupport_Fzzf               0.000230
# 723) blueJungle_Khynm               0.000230
# 724) blueJungle_DimaJke             0.000230
# 725) blueADC_YutoriMoyashi          0.000229
# 726) blueADC_Loken                  0.000229
# 727) redMiddle_niQ760               0.000229
# 728) redTop_Cejlon                  0.000229
# 729) blueJungle_Tussle              0.000228
# 730) redADC_Vasilii                 0.000228
# 731) redTop_Avalon                  0.000228
# 732) blueSupport_Jactroll           0.000228
# 733) redJungle_Euphony              0.000227
# 734) blueSupport_Bubbadub           0.000227
# 735) blueJungle_TusiN               0.000227
# 736) redJungle_Airwaks              0.000226
# 737) redSupport_Codpiece            0.000226
# 738) blueTop_exciting               0.000226
# 739) blueMiddle_Pawn                0.000226
# 740) blueJungle_Broxah              0.000226
# 741) blueMiddle_Rakyz               0.000225
# 742) redTop_Phaxi                   0.000225
# 743) redADC_GodJJ                   0.000225
# 744) redSupport_Stuntopolis         0.000225
# 745) redTop_AJun                    0.000225
# 746) blueJungle_Kenny               0.000225
# 747) blueJungle_Xayoo               0.000224
# 748) blueMiddle_Watdefox            0.000224
# 749) redTop_Paradise                0.000224
# 750) blueADC_Hologram               0.000224
# 751) blueTop_Taki                   0.000224
# 752) blueTop_Riris                  0.000223
# 753) blueSupport_Rogue              0.000223
# 754) blueJungle_Gemini              0.000223
# 755) redSupport_Jestkui Max         0.000223
# 756) blueMiddle_Ripi                0.000222
# 757) Rakan                          0.000222
# 758) redJungle_Corn                 0.000222
# 759) blueMiddle_Krastyel            0.000222
# 760) blueADC_Rkp                    0.000221
# 761) blueMiddle_Toyz                0.000221
# 762) redTop_FIRees                  0.000220
# 763) blueMiddle_Stone               0.000220
# 764) blueADC_LouisXGeeGee           0.000220
# 765) redTop_Flaresz                 0.000220
# 766) redTop_MapleSnow               0.000219
# 767) redADC_EzPrince                0.000218
# 768) redADC_LuNar                   0.000218
# 769) blueJungle_InKos               0.000218
# 770) blueADC_Rabi2                  0.000218
# 771) redADC_Stierlitz               0.000217
# 772) blueSupport_Voidle             0.000217
# 773) redMiddle_Piglet               0.000217
# 774) redJungle_Dimajke              0.000216
# 775) redSupport_BarneyD             0.000216
# 776) redMiddle_K                    0.000216
# 777) redSupport_YellOwStar          0.000216
# 778) blueJungle_Procxin             0.000216
# 779) redJungle_Crumbzz              0.000216
# 780) blueADC_MabreyBABY             0.000216
# 781) blueMiddle_Blanc               0.000216
# 782) blueADC_Raes                   0.000215
# 783) redTop_Rlun                    0.000215
# 784) blueSupport_Denian             0.000215
# 785) redJungle_Flaw                 0.000215
# 786) redMiddle_pr0lly               0.000215
# 787) redTop_Yue                     0.000214
# 788) redJungle_Dinter               0.000214
# 789) blueSupport_Swanepoel          0.000214
# 790) blueJungle_Rawbin              0.000214
# 791) redTop_Mouse                   0.000213
# 792) blueSupport_Minkywhale         0.000213
# 793) redSupport_Tolerant            0.000213
# 794) redMiddle_Marker               0.000213
# 795) blueJungle_Revolta             0.000212
# 796) blueSupport_Trance             0.000212
# 797) blueJungle_HOJIN               0.000212
# 798) redADC_Kid                     0.000211
# 799) redMiddle_Environmental        0.000211
# 800) Darius                         0.000211
# 801) blueSupport_EdWard             0.000210
# 802) blueADC_Zefa                   0.000210
# 803) Blitzcrank                     0.000210
# 804) blueADC_Amades                 0.000210
# 805) blueMiddle_xiaohu              0.000209
# 806) redADC_Stixxay                 0.000209
# 807) redJungle_Neiman               0.000209
# 808) blueMiddle_Sony                0.000209
# 809) redSupport_Hustlin             0.000209
# 810) redJungle_Rawbin               0.000209
# 811) blueTop_Dhokla                 0.000208
# 812) blueJungle_Pridestalker        0.000208
# 813) redJungle_Crystal              0.000208
# 814) blueMiddle_SuwaKo              0.000207
# 815) blueADC_otter                  0.000207
# 816) redADC_Frae                    0.000207
# 817) blueMiddle_Leonard             0.000207
# 818) redADC_nororin                 0.000206
# 819) blueTop_MapleSnow              0.000206
# 820) blueTop_Ever Crazy             0.000204
# 821) blueSupport_Kitties            0.000204
# 822) redSupport_Trance              0.000204
# 823) redADC_Toaster                 0.000204
# 824) redTop_M1st                    0.000204
# 825) blueADC_EzPrince               0.000204
# 826) blueJungle_NAZ                 0.000204
# 827) redTop_Praedyth                0.000204
# 828) Singed                         0.000203
# 829) redJungle_ShrimP               0.000203
# 830) blueSupport_Tilting            0.000203
# 831) blueSupport_Cotton             0.000202
# 832) redTop_SoaR                    0.000202
# 833) blueADC_MrRallez               0.000202
# 834) redJungle_Kez                  0.000202
# 835) blueADC_NaeMisa                0.000202
# 836) redTop_Rhux                    0.000201
# 837) blueMiddle_Gate                0.000201
# 838) redTop_Kazu                    0.000200
# 839) redJungle_Punisher             0.000200
# 840) blueMiddle_Doinb               0.000200
# 841) blueMiddle_Lucete              0.000199
# 842) blueTop_Pabu                   0.000199
# 843) blueJungle_ShorterACE          0.000199
# 844) redTop_Allorim                 0.000199
# 845) blueJungle_Kez                 0.000198
# 846) redJungle_Kenny                0.000198
# 847) redMiddle_Rakyz                0.000198
# 848) blueTop_alleycat               0.000197
# 849) redJungle_Procxin              0.000197
# 850) blueTop_SmittyJ                0.000197
# 851) redMiddle_SorenXD              0.000196
# 852) redTop_Brandini                0.000196
# 853) redSupport_Olleh               0.000196
# 854) redADC_Kimi                    0.000195
# 855) blueSupport_Ella               0.000195
# 856) blueTop_Paz                    0.000194
# 857) blueTop_Brolia                 0.000194
# 858) blueMiddle_Shiphtur            0.000194
# 859) redMiddle_Praedyth             0.000193
# 860) redMiddle_Krastyel             0.000193
# 861) redTop_Pabu                    0.000193
# 862) redMiddle_Perkz                0.000193
# 863) redMiddle_Watdefox             0.000193
# 864) redSupport_KEITHMCBRIEF        0.000193
# 865) blueMiddle_tei                 0.000193
# 866) blueJungle_Watch               0.000192
# 867) redTop_Dhokla                  0.000192
# 868) redTop_Roach                   0.000192
# 869) blueSupport_SaNTS              0.000192
# 870) redTop_Kulo                    0.000192
# 871) redADC_CoreJJ                  0.000191
# 872) blueMiddle_Shinmori            0.000191
# 873) redTop_Overpow                 0.000191
# 874) redMiddle_tei                  0.000191
# 875) blueMiddle_pr0lly              0.000190
# 876) blueADC_Safir                  0.000190
# 877) redSupport_mithy               0.000189
# 878) blueJungle_TBQ                 0.000189
# 879) redJungle_kimi                 0.000188
# 880) blueMiddle_wtcN                0.000188
# 881) blueMiddle_ChrisMisTrees       0.000188
# 882) blueMiddle_Eika                0.000188
# 883) redSupport_Never               0.000188
# 884) redADC_brTT                    0.000187
# 885) blueTop_SatoRy                 0.000187
# 886) redADC_Achuu Cop               0.000187
# 887) blueSupport_Yue                0.000187
# 888) Diana                          0.000187
# 889) redADC_Vander                  0.000187
# 890) blueADC_Sou                    0.000187
# 891) blueJungle_MiMo                0.000186
# 892) redJungle_CarilRui             0.000186
# 893) blueTop_3z                     0.000186
# 894) blueSupport_Suppa              0.000186
# 895) blueTop_Stark                  0.000186
# 896) blueSupport_SirNukesAlot       0.000185
# 897) redSupport_Rain                0.000185
# 898) redMiddle_NasesUyno            0.000185
# 899) blueTop_Aotaka                 0.000185
# 900) blueSupport_Tgun               0.000184
# 901) blueJungle_LEE                 0.000184
# 902) redMiddle_Gluppy               0.000184
# 903) blueJungle_Sigma               0.000183
# 904) redADC_Raes                    0.000183
# 905) blueTop_Rhux                   0.000183
# 906) blueTop_indra                  0.000183
# 907) blueJungle_Wulala              0.000183
# 908) redSupport_Skash               0.000183
# 909) redJungle_isurugi              0.000182
# 910) redADC_Upset                   0.000182
# 911) redJungle_PvPStejos            0.000182
# 912) redSupport_promisq             0.000182
# 913) redTop_Ninuo                   0.000181
# 914) blueMiddle_Piglet              0.000181
# 915) blueJungle_Chaser              0.000181
# 916) blueADC_Hans sama              0.000181
# 917) redJungle_Broxah               0.000181
# 918) blueSupport_Klaj               0.000180
# 919) blueADC_CorGi                  0.000180
# 920) blueADC_Optimas                0.000180
# 921) blueJungle_Rudy                0.000180
# 922) blueSupport_Baby               0.000180
# 923) redSupport_Gorilla             0.000179
# 924) redJungle_InKos                0.000179
# 925) blueSupport_Dumbledoge         0.000179
# 926) redADC_OB5                     0.000179
# 927) blueJungle_Dexter              0.000179
# 928) redTop_Hioss                   0.000178
# 929) redADC_ZeroZeroYon             0.000178
# 930) redTop_kev1n                   0.000178
# 931) redTop_Lilac                   0.000177
# 932) blueJungle_Comeback            0.000177
# 933) blueMiddle_Vash                0.000177
# 934) blueMiddle_LongB Gncm          0.000177
# 935) redMiddle_Gate                 0.000176
# 936) redMiddle_Ninja                0.000176
# 937) redJungle_LEE                  0.000176
# 938) redADC_Kz                      0.000176
# 939) blueSupport_Chunkyfresh        0.000176
# 940) blueTop_Pacman                 0.000175
# 941) redADC_Chelly                  0.000175
# 942) blueADC_Rekkles                0.000175
# 943) blueSupport_sOnyky             0.000175
# 944) redADC_YutoriMoyashi           0.000175
# 945) redADC_Sonstar                 0.000175
# 946) redTop_Rascal                  0.000174
# 947) redMiddle_dyNquedo             0.000174
# 948) blueMiddle_uri                 0.000174
# 949) blueTop_Kazu                   0.000174
# 950) redSupport_Tyresse             0.000174
# 951) blueMiddle_Mugoon              0.000174
# 952) blueMiddle_Pirean              0.000174
# 953) blueMiddle_REMIND              0.000174
# 954) redADC_Elysion                 0.000174
# 955) blueADC_Lethilion              0.000173
# 956) redJungle_Adaniel              0.000173
# 957) redJungle_Snowlz               0.000173
# 958) blueTop_FIRees                 0.000172
# 959) redMiddle_Cotton               0.000172
# 960) redJungle_Empt2y               0.000172
# 961) blueSupport_Regret             0.000172
# 962) blueADC_ZeroZeroYon            0.000172
# 963) redADC_Loken                   0.000172
# 964) redMiddle_ChuChuZ              0.000171
# 965) redADC_CorGi                   0.000171
# 966) redMiddle_NighT                0.000170
# 967) blueJungle_Crystal             0.000170
# 968) blueTop_LEP                    0.000170
# 969) blueADC_Emperor                0.000170
# 970) blueADC_meanTnT                0.000170
# 971) redSupport_Tgun                0.000169
# 972) blueMiddle_FeniX               0.000169
# 973) redTop_Xyraz                   0.000169
# 974) redMiddle_LEYL U NEHAR         0.000169
# 975) blueJungle_ILLusion            0.000169
# 976) blueJungle_Four                0.000169
# 977) blueMiddle_Wulala              0.000168
# 978) blueSupport_Gorilla            0.000168
# 979) redJungle_Mlxg                 0.000168
# 980) redSupport_Jactroll            0.000168
# 981) redSupport_Sky                 0.000167
# 982) redADC_Zyzz                    0.000166
# 983) blueSupport_dodo8              0.000166
# 984) redMiddle_Siuman               0.000166
# 985) blueSupport_Vioreleeee         0.000166
# 986) blueADC_Stierlitz              0.000165
# 987) blueSupport_Dioud              0.000165
# 988) blueMiddle_Phantiks            0.000165
# 989) blueJungle_kimi                0.000165
# 990) redJungle_Reignover            0.000165
# 991) redJungle_Juves                0.000165
# 992) redJungle_Four                 0.000164
# 993) redJungle_Julaxe               0.000164
# 994) blueTop_Cabochard              0.000164
# 995) blueJungle_Kottenx             0.000164
# 996) blueJungle_Mister              0.000164
# 997) blueSupport_k1                 0.000164
# 998) redMiddle_Gears                0.000163
# 999) redJungle_Turtle               0.000163
# 1000) blueADC_Raps                   0.000163
# 1001) blueJungle_Shaunz              0.000163
# 1002) redMiddle_Shinmori             0.000163
# 1003) redTop_Pk                      0.000163
# 1004) blueMiddle_SaSin               0.000162
# 1005) blueMiddle_XiaoWeiXiao         0.000162
# 1006) blueJungle_Flaw                0.000162
# 1007) blueSupport_Wolf               0.000161
# 1008) blueTop_Soaz                   0.000161
# 1009) redJungle_KaKAO                0.000161
# 1010) blueJungle_Punch               0.000161
# 1011) blueTop_Pride                  0.000161
# 1012) redJungle_Impaler              0.000160
# 1013) Lux                            0.000160
# 1014) redMiddle_Paranoia             0.000160
# 1015) redSupport_Kitties             0.000160
# 1016) redMiddle_Rakin VPP            0.000160
# 1017) blueTop_Overpow                0.000160
# 1018) blueMiddle_Siuman              0.000160
# 1019) blueMiddle_mancloud            0.000159
# 1020) blueADC_Upset                  0.000159
# 1021) redTop_Soaz                    0.000159
# 1022) blueTop_kev1n                  0.000159
# 1023) Shen                           0.000158
# 1024) blueSupport_Shadow             0.000158
# 1025) redJungle_Trixucator           0.000158
# 1026) blueJungle_CarilRui            0.000158
# 1027) blueJungle_lira                0.000158
# 1028) redADC_maplestreet8            0.000158
# 1029) redSupport_Rogue               0.000158
# 1030) blueADC_padden                 0.000157
# 1031) redSupport_Verfix              0.000157
# 1032) redMiddle_XiaoWeiXiao          0.000157
# 1033) redJungle_WTHeaven             0.000157
# 1034) blueSupport_Chenxuan           0.000157
# 1035) blueJungle_Impaler             0.000157
# 1036) blueSupport_Olleh              0.000157
# 1037) redTop_Papryze                 0.000156
# 1038) blueSupport_NeedLess           0.000156
# 1039) redMiddle_Wulala               0.000156
# 1040) redMiddle_REMIND               0.000156
# 1041) blueMiddle_Lesmart             0.000156
# 1042) redSupport_EdWard              0.000156
# 1043) blueADC_Madnesss               0.000156
# 1044) blueMiddle_aripo               0.000156
# 1045) blueTop_WarriorLady            0.000155
# 1046) redADC_S Ysera                 0.000155
# 1047) redJungle_TaY                  0.000155
# 1048) Jhin                           0.000155
# 1049) blueSupport_un1tback           0.000154
# 1050) Shyvana                        0.000154
# 1051) blueMiddle_wrekt               0.000154
# 1052) blueTop_Phaxi                  0.000154
# 1053) blueTop_apaMEN                 0.000154
# 1054) redSupport_sOnyky              0.000154
# 1055) redSupport_Lounet              0.000153
# 1056) blueTop_Brandini               0.000153
# 1057) Kayle                          0.000153
# 1058) blueADC_Betty                  0.000153
# 1059) blueMiddle_Eli                 0.000153
# 1060) blueJungle_Empt2y              0.000153
# 1061) redTop_ZvenE                   0.000152
# 1062) blueSupport_Ralara             0.000152
# 1063) blueMiddle_tockers             0.000152
# 1064) redADC_tantrum                 0.000152
# 1065) blueADC_Jinjiao                0.000152
# 1066) blueMiddle_Rakin VPP           0.000152
# 1067) redTop_Stark                   0.000152
# ...
# 3190) blueSupport_WarL0cK            0.000002
# 3191) redMiddle_Drobovik123          0.000002
# 3192) redSupport_Veux                0.000002
# 3193) blueMiddle_Optimus             0.000002
# 3194) redSupport_Max                 0.000002
# 3195) blueADC_brTT RX                0.000002
# 3196) redMiddle_YoDa SL              0.000002
# 3197) blueTop_AmazingJ               0.000002
# 3198) redTop_Zonda                   0.000002
# 3199) blueMiddle_Shok                0.000002
# 3200) blueMiddle_Tempt               0.000002
# 3201) redJungle_SolidSnake           0.000002
# 3202) blueJungle_Kongyue             0.000002
# 3203) redADC_Rakin                   0.000002
# 3204) blueTop_PANKY                  0.000002
# 3205) redTop_KaKaRot                 0.000002
# 3206) blueMiddle_Energy              0.000002
# 3207) blueADC_Impactful              0.000002
# 3208) redJungle_Rod                  0.000002
# 3209) blueADC_Adryh                  0.000002
# 3210) blueSupport_Ben                0.000002
# 3211) redJungle_Viking               0.000002
# 3212) redSupport_Sweet               0.000002
# 3213) redJungle_Grig                 0.000002
# 3214) redJungle_betty                0.000002
# 3215) blueJungle_UmTi                0.000002
# 3216) blueTop_ADD                    0.000002
# 3217) blueMiddle_Rain                0.000002
# 3218) redMiddle_Wind                 0.000002
# 3219) blueJungle_Kreox               0.000002
# 3220) redMiddle_Frozen               0.000002
# 3221) blueTop_Gos                    0.000002
# 3222) redSupport_K                   0.000002
# 3223) blueJungle_loulex              0.000002
# 3224) blueSupport_Joey               0.000002
# 3225) blueTop_Rins                   0.000002
# 3226) redADC_Kramer                  0.000002
# 3227) blueMiddle_Maple               0.000002
# 3228) redTop_h4rdeath                0.000002
# 3229) redADC_Zigu                    0.000002
# 3230) blueSupport_Rogu               0.000002
# 3231) redMiddle_Keane                0.000002
# 3232) redJungle_once1                0.000002
# 3233) redSupport_SimSin              0.000001
# 3234) blueSupport_Eternal            0.000001
# 3235) blueADC_Wildturtle             0.000001
# 3236) redSupport_Rydle               0.000001
# 3237) blueADC_Altec                  0.000001
# 3238) blueTop_Cuvee                  0.000001
# 3239) blueTop_Eryon                  0.000001
# 3240) redTop_AJ                      0.000001
# 3241) redMiddle_LeeMid               0.000001
# 3242) blueJungle_beibei              0.000001
# 3243) redSupport_GuGer               0.000001
# 3244) blueADC_Ruvelius376            0.000001
# 3245) blueMiddle_Baeme               0.000001
# 3246) redADC_EvanRL                  0.000001
# 3247) blueMiddle_Rookie              0.000001
# 3248) redJungle_WIND                 0.000001
# 3249) redMiddle_Joy                  0.000001
# 3250) redSupport_Eason               0.000001
# 3251) blueSupport_ThreshMelon        0.000001
# 3252) redTop_Smurf                   0.000001
# 3253) blueTop_YoungBuck              0.000001
# 3254) blueTop_Cola                   0.000001
# 3255) redTop_jer0m                   0.000001
# 3256) redMiddle_Estelim              0.000001
# 3257) redTop_Parang                  0.000001
# 3258) redMiddle_Exileh               0.000001
# 3259) blueADC_WILDTURTLE             0.000001
# 3260) blueMiddle_Avenuee             0.000001
# 3261) blueADC_Raydere                0.000001
# 3262) blueSupport_Jockster           0.000001
# 3263) blueADC_Nuclear                0.000001
# 3264) redMiddle_zoiren               0.000001
# 3265) redTop_Rest                    0.000001
# 3266) redTop_Relic                   0.000001
# 3267) redTop_MayZ                    0.000001
# 3268) blueSupport_je suis kaas       0.000001
# 3269) blueJungle_Loulex              0.000001
# 3270) redADC_Juzinho                 0.000001
# 3271) blueTop_ikssu                  0.000001
# 3272) redTop_Miracle                 0.000001
# 3273) redTop_Armut                   0.000001
# 3274) blueSupport_QuietRain          0.000001
# 3275) blueJungle_porpoisepops        0.000001
# 3276) redMiddle_Energy               0.000001
# 3277) blueMiddle_Wish                0.000001
# 3278) blueTop_Rare                   0.000001
# 3279) redSupport_Raise               0.000001
# 3280) redADC_Bang                    0.000001
# 3281) blueSupport_Nevan              0.000001
# 3282) blueMiddle_Wako                0.000001
# 3283) blueJungle_H0R0                0.000001
# 3284) redTop_Cola                    0.000001
# 3285) redJungle_Svenskeren           0.000001
# 3286) blueJungle_Peanut              0.000001
# 3287) redJungle_Rawbin IV            0.000001
# 3288) blueTop_Armut                  0.000001
# 3289) blueTop_CuVee                  0.000001
# 3290) blueMiddle_Swiffer             0.000001
# 3291) redSupport_S HoHotDoG          0.000001
# 3292) blueMiddle_Drobovik123         0.000001
# 3293) blueADC_Padden                 0.000001
# 3294) redSupport_Terap1st            0.000001
# 3295) blueMiddle_Flashy              0.000000
# 3296) redADC_S RD                    0.000000
# 3297) redJungle_Doxy                 0.000000
# 3298) blueADC_Zven                   0.000000
# 3299) blueJungle_Auspexa             0.000000
# 3300) redJungle_Theokoles            0.000000
# 3301) redADC_Steeelback              0.000000
# 3302) redMiddle_Kami                 0.000000
# 3303) redJungle_Eve                  0.000000
# 3304) blueADC_Nardeus                0.000000
# 3305) redJungle_AnOnPsyCkO           0.000000
# 3306) redJungle_Duxen                0.000000
# 3307) redJungle_Coma                 0.000000
# 3308) redADC_Padden                  0.000000
# 3309) blueSupport_Rydle              0.000000
# 3310) blueMiddle_Joy                 0.000000
# 3311) redSupport_Joey                0.000000
# 3312) redMiddle_Ggoong               0.000000
# 3313) blueTop_Zonda                  0.000000
# 3314) redADC_Bomb                    0.000000
# 3315) blueMiddle_Cheong              0.000000
# 3316) blueADC_Crayzee                0.000000
# 3317) redADC_HoNeyRain               0.000000
# 3318) redADC_Lactea                  0.000000
# 3319) blueADC_Krislund               0.000000
# 3320) blueADC_Celaver                0.000000
# 3321) redMiddle_Glup                 0.000000
# 3322) redADC_Adryh                   0.000000
# 3323) redADC_NoA                     0.000000
# 3324) redADC_Crayzee                 0.000000
# 3325) blueMiddle_Tiridus             0.000000
# 3326) redSupport_Blumigan            0.000000
# 3327) blueSupport_Riyev              0.000000
# 3328) blueADC_Steeelbackkk           0.000000
# 3329) redJungle_NoName               0.000000
# 3330) blueMiddle_SozPurefect         0.000000
# 3331) blueADC_Ruve Sama              0.000000
# 3332) redSupport_Eternal             0.000000
# 3333) blueMiddle_nukeduck            0.000000
# 3334) redSupport_SkuLL               0.000000
# 3335) blueJungle_Empt2               0.000000
# 3336) blueSupport_K                  0.000000
# 3337) redADC_Nardeus                 0.000000
# 3338) blueMiddle_Slooshi8            0.000000
# 3339) blueSupport_Altec              0.000000
# 3340) redJungle_Yaelay               0.000000
# 3341) redJungle_Krvavy               0.000000
# 3342) redTop_fredy122                0.000000
# 3343) redJungle_bono                 0.000000
# 3344) redADC_Nuclear                 0.000000
# 3345) redSupport_SaNTas              0.000000
# 3346) redADC_WhiteLotus              0.000000
# 3347) blueJungle_Minerva             0.000000
# 3348) redTop_Eryon                   0.000000
# 3349) blueADC_Raison                 0.000000
# 3350) redSupport_Makro               0.000000
# 3351) redTop_Jwaow                   0.000000
# 3352) blueADC_Squidgy                0.000000
# 3353) redSupport_Sony                0.000000
# 3354) blueADC_Sneaky                 0.000000
# 3355) redJungle_DoubleAiM            0.000000
# 3356) blueADC_Blinky                 0.000000
# 3357) blueADC_Sheriff                0.000000
# 3358) blueADC_Sedrion                0.000000
# 3359) blueADC_BeBe                   0.000000
# 3360) blueADC_Honos                  0.000000
# 3361) blueADC_Bomb                   0.000000
# 3362) redMiddle_Triple               0.000000
# 3363) redMiddle_Tinowns              0.000000
# 3364) redSupport_Saviour             0.000000
# 3365) blueADC_Hoofspark              0.000000
# 3366) redMiddle_Takefun              0.000000
# 3367) blueADC_Unified                0.000000
# 3368) redSupport_Stunt               0.000000
# 3369) blueADC_momo                   0.000000
# 3370) redMiddle_Shernfire            0.000000
# 3371) blueADC_Zeitnot                0.000000
# 3372) redMiddle_Rookie               0.000000
# 3373) redSupport_QuietRain           0.000000
# 3374) blueADC_Luskka                 0.000000
# 3375) redJungle_=                    0.000000
# 3376) blueADC_MaHa                   0.000000
# 3377) MissFortune                    0.000000
# 3378) blueADC_Lactea                 0.000000
# 3379) redSupport_Whyin               0.000000
# 3380) blueADC_cop                    0.000000
# 3381) blueADC_Freeze                 0.000000
# 3382) blueADC_Creaton                0.000000
# 3383) redJungle_Dan                  0.000000
# 3384) redSupport_Newbie              0.000000
# 3385) redTop_Mylon                   0.000000
# 3386) blueADC_Gankzero               0.000000
# 3387) blueADC_NoA                    0.000000
# 3388) redMiddle_corn                 0.000000
# 3389) redSupport_Targamas            0.000000
# 3390) Ezreal                         0.000000
# 3391) blueADC_Stixxay                0.000000
# 3392) redJungle_Clearlove7           0.000000
# 3393) redTop_Gamsu                   0.000000
# 3394) blueADC_Steeelback             0.000000
# 3395) blueADC_Keith                  0.000000
# 3396) redMiddle_Rain                 0.000000
# 3397) redMiddle_Wish                 0.000000
# 3398) blueADC_K                      0.000000
# 3399) redSupport_MounTain            0.000000
# 3400) blueJungle_Jankos              0.000000
# 3401) blueJungle_xani                0.000000
# 3402) redADC_Tiger                   0.000000
# 3403) blueMiddle_Takefun             0.000000
# 3404) redADC_Vizility                0.000000
# 3405) blueSupport_Nestea             0.000000
# 3406) redADC_Veritas                 0.000000
# 3407) blueMiddle_Roki                0.000000
# 3408) blueTop_Thulz                  0.000000
# 3409) redTop_b4dd                    0.000000
# 3410) Taric                          0.000000
# 3411) blueTop_Vayn3z                 0.000000
# 3412) blueSupport_Raise              0.000000
# 3413) redADC_Honos                   0.000000
# 3414) redADC_Hoofspark               0.000000
# 3415) redADC_Teddy                   0.000000
# 3416) blueTop_Wunderwear             0.000000
# 3417) redADC_Wildturtle              0.000000
# 3418) blueMiddle_Triple              0.000000
# 3419) blueTop_SazaHu                 0.000000
# 3420) blueMiddle_YoDa SL             0.000000
# 3421) blueMiddle_corn                0.000000
# 3422) redADC_Zeitnot                 0.000000
# 3423) blueMiddle_emp                 0.000000
# 3424) redADC_Blinky                  0.000000
# 3425) blueSupport_Lillebelt          0.000000
# 3426) blueMiddle_takeshi             0.000000
# 3427) blueSupport_Legato             0.000000
# 3428) blueTop_Profit                 0.000000
# 3429) redJungle_xani                 0.000000
# 3430) redADC_brTT RX                 0.000000
# 3431) redTop_Wunderwear              0.000000
# 3432) redJungle_woofi                0.000000
# 3433) blueSupport_KiWiKiD            0.000000
# 3434) redTop_brTT RX                 0.000000
# 3435) redADC_Jynthe                  0.000000
# 3436) blueMiddle_Naru                0.000000
# 3437) redMiddle_Apex                 0.000000
# 3438) blueMiddle_Cheese              0.000000
# 3439) redTop_padden                  0.000000
# 3440) blueMiddle_Dumbledoge          0.000000
# 3441) blueSupport_Terap1st           0.000000
# 3442) redTop_numlocked               0.000000
# 3443) blueSupport_TusiN              0.000000
# 3444) redMiddle_Abbedagge            0.000000
# 3445) blueMiddle_Bma                 0.000000
# 3446) blueSupport_Sweet              0.000000
# 3447) blueMiddle_FoFo                0.000000
# 3448) blueSupport_Veux               0.000000
# 3449) blueMiddle_Backlund            0.000000
# 3450) blueSupport_Sony               0.000000
# 3451) blueMiddle_Apex                0.000000
# 3452) redMiddle_Avenuee              0.000000
# 3453) blueMiddle_Morning             0.000000
# 3454) blueMiddle_Abbedagge           0.000000
# 3455) redADC_SSol                    0.000000
# 3456) blueMiddle_Hatrixx             0.000000
# 3457) redMiddle_Backlund             0.000000
# 3458) redADC_SacyR                   0.000000
# 3459) blueTop_numlocked              0.000000
# 3460) redADC_Sarkis                  0.000000
# 3461) blueSupport_SaNTaS             0.000000
# 3462) blueSupport_Whyin              0.000000
# 3463) redADC_Lost                    0.000000
# 3464) redADC_LilV                    0.000000
# 3465) blueMiddle_LeeMid              0.000000
# 3466) blueTop_Zvene                  0.000000
# 3467) blueTop_Zantins                0.000000
# 3468) redADC_momo                    0.000000
# 3469) blueSupport_Kazu               0.000000
# 3470) blueTop_NasesUyno              0.000000
# 3471) redJungle_HanJi                0.000000
# 3472) blueTop_Buggax                 0.000000
# 3473) blueJungle_Rod                 0.000000
# 3474) blueTop_BoBo                   0.000000
# 3475) redMiddle_Maple                0.000000
# 3476) redJungle_Levi                 0.000000
# 3477) blueTop_Beansu                 0.000000
# 3478) redJungle_Kongyue              0.000000
# 3479) blueJungle_SirT                0.000000
# 3480) blueSupport_Blumigan           0.000000
# 3481) redTop_Cube                    0.000000
# 3482) blueJungle_Tay                 0.000000
# 3483) redJungle_Jankos               0.000000
# 3484) blueSupport_Barcode            0.000000
# 3485) redJungle_IWDominate           0.000000
# 3486) redJungle_Halpern              0.000000
# 3487) blueJungle_Rawbin IV           0.000000
# 3488) blueTop_AJ                     0.000000
# 3489) blueSupport_Arphan             0.000000
# 3490) redMiddle_Morning              0.000000
# 3491) redTop_Elwind                  0.000000
# 3492) blueJungle_Zuao                0.000000
# 3493) redSupport_Hakuho              0.000000
# 3494) redMiddle_Naru                 0.000000
# 3495) redJungle_Fiesta               0.000000
# 3496) redSupport_Imagine             0.000000
# 3497) redTop_Riris                   0.000000
# 3498) blueJungle_mlxg                0.000000
# 3499) Trundle                        0.000000
# 3500) blueJungle_shernfire           0.000000
# 3501) blueJungle_wind                0.000000
# 3502) redJungle_Memento              0.000000
# 3503) redJungle_Move                 0.000000
# 3504) redTop_Vayn3z                  0.000000
# 3505) redJungle_TeamleSS             0.000000
# 3506) blueTop_Mylon                  0.000000
# 3507) redJungle_loulex               0.000000
# 3508) blueJungle_Clearlove7          0.000000
# 3509) redTop_Akunma                  0.000000
# 3510) redTop_AmazingJ                0.000000
# 3511) redMiddle_Gear                 0.000000
# 3512) blueSupport_Imagine            0.000000
# 3513) redTop_Atyamomo                0.000000
# 3514) redMiddle_Goldenglue           0.000000
# 3515) redSupport_Ben                 0.000000
# 3516) blueJungle_Doxy                0.000000
# 3517) blueSupport_Hakuho             0.000000
# 3518) blueTop_K                      0.000000
# 3519) blueSupport_GuGer              0.000000
# 3520) redTop_BOSS                    0.000000
# 3521) redTop_CaliTrlolz8             0.000000
# 3522) redSupport_Boris               0.000000
# 3523) blueJungle_K                   0.000000
# 3524) blueJungle_Levi                0.000000
# 3525) blueJungle_LirA                0.000000
# 3526) blueJungle_MayZ                0.000000
# 3527) blueTop_Elwind                 0.000000
# 3528) blueJungle_MiHanna             0.000000
# 3529) redTop_Buggax                  0.000000
# 3530) blueJungle_Muscle              0.000000
# 3531) blueTop_Dark Solece            0.000000
# 3532) blueSupport_Choisix            0.000000
# 3533) blueTop_Crazy                  0.000000
# 3534) blueJungle_Praelus             0.000000
# 3535) redJungle_Nappon               0.000000
# 3536) blueSupport_Professor          0.000000

# %% [markdown]
# # Training Data with Different Models

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(penalty='l1',n_iter=100, eta0=1, random_state=1)
ppn.fit(X_train, y_train)

print('accuracy of trainning = ' ,ppn.score(X_train,y_train))
print('accuracy of testing = ' ,ppn.score(X_test,y_test))
# Out:
# accuracy of trainning =  0.841957255343
# accuracy of testing =  0.65791776028

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(penalty='l1',C=1,random_state=1)   
lr.fit(X_train, y_train)
print('accuracy of trainning = ' ,lr.score(X_train,y_train))
print('accuracy of testing = ' ,lr.score(X_test,y_test))
# Out:
# accuracy of trainning =  0.740907386577
# accuracy of testing =  0.715223097113

# %% [markdown]
# <br>
# <br>
